# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file=pd.read_csv("SemEvalTrain.csv",error_bad_lines=False,delimiter='\t')
file
# Out:
# b'Skipping line 1761: expected 4 fields, saw 5\nSkipping line 3104: expected 4 fields, saw 5\n'
#                      ID1        ID2             Sentiment  \
# 0     264183816548130816   15140428              positive
# 1     264249301910310912   18516728              negative
# 2     264105751826538497  147088367              positive
# 3     264094586689953794  332474633              negative
# 4     254941790757601280  557103111              negative
# 5     264169034155696130  382403760               neutral
# 6     263192091700654080  344222239  objective-OR-neutral
# 7     260200142420992000  332530284             objective
# 8     263304719471087617  564843841             objective
# 9     263975113404342273  616166780             objective
# 10    257343699460173824   10115042              positive
# 11    257239661976625152   64642600  objective-OR-neutral
# 12    264041764460036096  198706982              positive
# ...

# %%
file=file[file.columns[-2:]]
file
# Out:
#                  Sentiment                                              Tweet
# 0                 positive  Gas by my house hit $3.39!!!! I'm going to Cha...
# 1                 negative  Iranian general says Israel's Iron Dome can't ...
# 2                 positive  with J Davlar 11th. Main rivals are team Polan...
# 3                 negative  Talking about ACT's && SAT's, deciding where I...
# 4                 negative  They may have a SuperBowl in Dallas, but Dalla...
# 5                  neutral  Im bringing the monster load of candy tomorrow...
# 6     objective-OR-neutral  Apple software, retail chiefs out in overhaul:...
# 7                objective  #Livewire Nadal confirmed for Mexican Open in ...
# 8                objective  #Iran US delisting MKO from global terrorists ...
# 9                objective  Expect light-moderate rains over E. Visayas; C...
# 10                positive  One ticket left for the @49ers game tomorrow! ...
# ...

# %%
file['Sentiment']=file['Sentiment'].apply(lambda x: 'neutral' if 'objective' in x else x )

# %%
file['Sentiment'].unique()
# Out:
# array(['positive', 'negative', 'neutral'], dtype=object)

# %%
file.groupby(['Sentiment']).count().plot(kind='bar')
plt.show()

# %%
file.groupby(['Sentiment']).count().plot

# %%
type()
# Out:
# pandas.core.frame.DataFrame

# %%
file['lengths']=file['Tweet'].apply(lambda x: len(x.split(" ")))
ax.set_xlabel("x label")

# %%
graph=file.groupby('lengths').count()['Sentiment'].plot(kind='bar')
graph.set_xlabel('Tweet length')
graph.set_ylabel('Counts')
plt.show()

# %%
file.groupby('lengths').count()

# %%
file2
# Out:
#           ItemID  Sentiment SentimentSource  \
# 0              1          0    Sentiment140
# 1              2          0    Sentiment140
# 2              3          1    Sentiment140
# 3              4          0    Sentiment140
# 4              5          0    Sentiment140
# 5              6          0    Sentiment140
# 6              7          1    Sentiment140
# 7              8          0    Sentiment140
# 8              9          1    Sentiment140
# 9             10          1    Sentiment140
# 10            11          0    Sentiment140
# 11            12          1    Sentiment140
# 12            13          0    Sentiment140
# 13            14          0    Sentiment140
# 14            15          0    Sentiment140
# 15            16          0    Sentiment140
# 16            17          0    Sentiment140
# 17            18          1    Sentiment140
# 18            19          0    Sentiment140
# 19            20          0    Sentiment140
# ...

# %%
file2=pd.read_csv("Sentiment_Analysis Dataset.csv",error_bad_lines=False)
# Out:
# b'Skipping line 8836: expected 4 fields, saw 5\n'
# b'Skipping line 535882: expected 4 fields, saw 7\n'

# %%
file2['lengths']=file2['SentimentText'].apply(lambda x: len(x.split(" ")))

graph=file2.groupby('lengths').count()['SentimentText'][0:35].plot(kind='bar',figsize=(20,10),fontsize=12)
graph.set_xlabel('Tweet length')
graph.set_ylabel('Counts')
plt.show()

# %%
file2['Sentiment']=file2['Sentiment'].apply(lambda x: 'positive' if x==1 else 'negative')

# %%
graph3=file2.groupby('Sentiment')['SentimentText'].count().plot(kind='bar')
plt.show()

# %%
# Out:
#          ItemID  Sentiment  SentimentSource  SentimentText
# lengths
# 2          3988       3988             3988           3988
# 3         20041      20041            20041          20041
# 4         44332      44332            44332          44332
# 5         62623      62623            62623          62623
# 6         77346      77346            77346          77346
# 7         85130      85130            85130          85130
# 8         87343      87343            87343          87343
# 9         87255      87255            87255          87255
# 10        85869      85869            85869          85869
# 11        82283      82283            82283          82283
# 12        79803      79803            79803          79803
# 13        75356      75356            75356          75356
# 14        71595      71595            71595          71595
# 15        67404      67404            67404          67404
# 16        63527      63527            63527          63527
# ...
